# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.linear_model import LinearRegression, LogisticRegression
# %matplotlib inline

housing_data = pd.read_csv("Housing_Data.csv")
housing_data.head(25)
# Out:
#     Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.458574             5.682861                   7.009188
# 1       79248.642455             6.002900                   6.730821
# 2       61287.067179             5.865890                   8.512727
# 3       63345.240046             7.188236                   5.586729
# 4       59982.197226             5.040555                   7.839388
# 5       80175.754159             4.988408                   6.104512
# 6       64698.463428             6.025336                   8.147760
# 7       78394.339278             6.989780                   6.620478
# 8       59927.660813             5.362126                   6.393121
# 9       81885.927184             4.423672                   8.167688
# 10      80527.472083             8.093513                   5.042747
# 11      50593.695497             4.496513                   7.467627
# 12      39033.809237             7.671755                   7.250029
# 13      73163.663441             6.919535                   5.993188
# 14      69391.380184             5.344776                   8.406418
# 15      73091.866746             5.443156                   8.517513
# 16      79706.963058             5.067890                   8.219771
# 17      61929.077018             4.788550                   5.097010
# 18      63508.194299             5.947165                   7.187774
# 19      62085.276403             5.739411                   7.091808
# 20      86294.999089             6.627457                   8.011898
# 21      60835.089979             5.551222                   6.517175
# 22      64490.650267             4.210323                   5.478088
# 23      60697.351539             6.170484                   7.150537
# 24      59748.855487             5.339340                   7.748682
#
#     Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                           4.09     23086.800503  1.059034e+06
# 1                           3.09     40173.072174  1.505891e+06
# 2                           5.13     36882.159400  1.058988e+06
# 3                           3.26     34310.242831  1.260617e+06
# 4                           4.23     26354.109472  6.309435e+05
# 5                           4.04     26748.428425  1.068138e+06
# 6                           3.41     60828.249085  1.502056e+06
# 7                           2.42     36516.358972  1.573937e+06
# 8                           2.30     29387.396003  7.988695e+05
# 9                           6.10     40149.965749  1.545155e+06
# 10                          4.10     47224.359840  1.707046e+06
# 11                          4.49     34343.991886  6.637324e+05
# 12                          3.10     39220.361467  1.042814e+06
# 13                          2.27     32326.123139  1.291332e+06
# 14                          4.37     35521.294033  1.402818e+06
# 15                          4.01     23929.524053  1.306675e+06
# 16                          3.12     39717.813576  1.556787e+06
# 17                          4.30     24595.901498  5.284852e+05
# 18                          5.12     35719.653052  1.019426e+06
# 19                          5.49     44922.106702  1.030591e+06
# 20                          4.07     47560.775336  2.146925e+06
# 21                          2.10     45574.741662  9.292476e+05
# 22                          4.31     40358.960106  7.188872e+05
# 23                          6.34     28140.967088  7.439998e+05
# 24                          4.23     27809.986544  8.957371e+05
#
#                                               Address
# 0   208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1   188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2   9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                           USS Barnett\nFPO AP 44820
# 4                          USNS Raymond\nFPO AE 09386
# 5   06039 Jennifer Islands Apt. 443\nTracyport, KS...
# 6   4759 Daniel Shoals Suite 442\nNguyenburgh, CO ...
# 7      972 Joyce Viaduct\nLake William, TN 17778-6483
# 8                           USS Gilbert\nFPO AA 20957
# 9                    Unit 9446 Box 0958\nDPO AE 97025
# 10  6368 John Motorway Suite 700\nJanetbury, NM 26854
# 11  911 Castillo Park Apt. 717\nDavisborough, PW 7...
# 12  209 Natasha Stream Suite 961\nHuffmanland, NE ...
# 13  829 Welch Track Apt. 992\nNorth John, AR 26532...
# 14                   PSC 5330, Box 4420\nAPO AP 08302
# 15     2278 Shannon View\nNorth Carriemouth, NM 84617
# 16   064 Hayley Unions\nNicholsborough, HI 44161-1887
# 17      5498 Rachel Locks\nNew Gregoryshire, PW 54755
# 18                   Unit 7424 Box 2786\nDPO AE 71255
# 19    19696 Benjamin Cape\nStephentown, ME 36952-4733
# 20  030 Larry Park Suite 665\nThomashaven, HI 8794...
# 21                           USNS Brown\nFPO AP 85833
# 22          95198 Ortiz Key\nPort Sara, TN 24541-2855
# 23  9003 Jay Plains Suite 838\nLake Elizabeth, IN ...
# 24       24282 Paul Valley\nWest Perry, MI 03169-5806

# %%
X = housing_data[['Avg. Area Income','Avg. Area House Age','Avg. Area Number of Rooms','Avg. Area Number of Bedrooms','Area Population']]
y = housing_data['Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
print(regressor.intercept_)
# Out:
# -2644850.0694553573

# %%
plt.scatter(y_test, y_pred)

# %%
mae = metrics.mean_absolute_error(y_test, y_pred)
print(mae)
# Out:
# 81832.71748622792

# %%
mse = metrics.mean_squared_error(y_test, y_pred)
print(mse)
# Out:
# 10401275405.858944

# %%
r2 = metrics.r2_score(y_test, y_pred)
print(r2)
# Out:
# 0.918508746677805

# %%
corr = X.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_ea4cd_row0_col0, #T_ea4cd_row1_col1, #T_ea4cd_row2_col2, #T_ea4cd_row3_col3, #T_ea4cd_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ea4cd_row0_col1 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_ea4cd_row0_col2, #T_ea4cd_row1_col2, #T_ea4cd_row1_col4, #T_ea4cd_row3_col4, #T_ea4cd_row4_col0, #T_ea4cd_row4_col1, #T_ea4cd_row4_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ea4cd_row0_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_ea4cd_row0_col4, #T_ea4cd_row2_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_ea4cd_row1_col0, #T_ea4cd_row4_col2 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_ea4cd_row1_col3 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_ea4cd_row2_col1 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_ea4cd_row2_col3 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_ea4cd_row2_col4, #T_ea4cd_row3_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_ea4cd_row3_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_ea4cd_row3_col2 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# </style>
# <table id="T_ea4cd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea4cd_level0_col0" class="col_heading level0 col0" >Avg. Area Income</th>
#       <th id="T_ea4cd_level0_col1" class="col_heading level0 col1" >Avg. Area House Age</th>
#       <th id="T_ea4cd_level0_col2" class="col_heading level0 col2" >Avg. Area Number of Rooms</th>
#       <th id="T_ea4cd_level0_col3" class="col_heading level0 col3" >Avg. Area Number of Bedrooms</th>
#       <th id="T_ea4cd_level0_col4" class="col_heading level0 col4" >Area Population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea4cd_level0_row0" class="row_heading level0 row0" >Avg. Area Income</th>
#       <td id="T_ea4cd_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_ea4cd_row0_col1" class="data row0 col1" >-0.002007</td>
#       <td id="T_ea4cd_row0_col2" class="data row0 col2" >-0.011032</td>
#       <td id="T_ea4cd_row0_col3" class="data row0 col3" >0.019788</td>
#       <td id="T_ea4cd_row0_col4" class="data row0 col4" >-0.016234</td>
#     </tr>
#     <tr>
#       <th id="T_ea4cd_level0_row1" class="row_heading level0 row1" >Avg. Area House Age</th>
#       <td id="T_ea4cd_row1_col0" class="data row1 col0" >-0.002007</td>
#       <td id="T_ea4cd_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_ea4cd_row1_col2" class="data row1 col2" >-0.009428</td>
#       <td id="T_ea4cd_row1_col3" class="data row1 col3" >0.006149</td>
#       <td id="T_ea4cd_row1_col4" class="data row1 col4" >-0.018743</td>
#     </tr>
#     <tr>
#       <th id="T_ea4cd_level0_row2" class="row_heading level0 row2" >Avg. Area Number of Rooms</th>
#       <td id="T_ea4cd_row2_col0" class="data row2 col0" >-0.011032</td>
#       <td id="T_ea4cd_row2_col1" class="data row2 col1" >-0.009428</td>
#       <td id="T_ea4cd_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_ea4cd_row2_col3" class="data row2 col3" >0.462695</td>
#       <td id="T_ea4cd_row2_col4" class="data row2 col4" >0.002040</td>
#     </tr>
#     <tr>
#       <th id="T_ea4cd_level0_row3" class="row_heading level0 row3" >Avg. Area Number of Bedrooms</th>
#       <td id="T_ea4cd_row3_col0" class="data row3 col0" >0.019788</td>
#       <td id="T_ea4cd_row3_col1" class="data row3 col1" >0.006149</td>
#       <td id="T_ea4cd_row3_col2" class="data row3 col2" >0.462695</td>
#       <td id="T_ea4cd_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_ea4cd_row3_col4" class="data row3 col4" >-0.022168</td>
#     </tr>
#     <tr>
#       <th id="T_ea4cd_level0_row4" class="row_heading level0 row4" >Area Population</th>
#       <td id="T_ea4cd_row4_col0" class="data row4 col0" >-0.016234</td>
#       <td id="T_ea4cd_row4_col1" class="data row4 col1" >-0.018743</td>
#       <td id="T_ea4cd_row4_col2" class="data row4 col2" >0.002040</td>
#       <td id="T_ea4cd_row4_col3" class="data row4 col3" >-0.022168</td>
#       <td id="T_ea4cd_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
